# %% [markdown]
# Source: https://www.youtube.com/watch?v=vB8SleIKlcw [17.12.2021]
#
# Source: https://www.youtube.com/watch?v=WvoLTXIjBYU [17.12.2021]
#
# Source: https://www.youtube.com/watch?v=wQ8BIBpya2k&t [18.12.2021]
#
# Source https://www.youtube.com/watch?v=uqomO_BZ44g&t=8s [19.12.2021]
#
# Source: https://thispointer.com/python-get-list-of-files-in-directory-sorted-by-name/ [20.12.2021]
#
# Source: https://www.youtube.com/watch?v=j-3vuBynnOE&t=889s [20.12.2021]
#
# Source: https://wiki.python.org/moin/UsingPickle [21.12.2021]
#
# Source: https://stackoverflow.com/questions/39283358/keras-how-to-record-validation-loss/39291417 [01.01.2022]
#
# Source: https://stackoverflow.com/questions/64666917/optuna-memory-issues [01.01.2022]

# %%
# !pip install optuna

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from sklearn.metrics import mean_squared_error
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import keras.backend as K
import optuna
from keras.callbacks import ModelCheckpoint
import keras

# %% [markdown]
# Set the height and width of the training pictures

# %%
width = 60
height = 34

# %% [markdown]
# Load the training data

# %%
training_data = pickle.load(open('drive/MyDrive/Bachelorarbeit/Datensatz/Bilder/Bilder 60x34/cs01_' + str(width) + 'x' + str(height) + '.pkl', 'rb'))
training_data += pickle.load(open('drive/MyDrive/Bachelorarbeit/Datensatz/Bilder/Bilder 60x34/cs02_' + str(width) + 'x' + str(height) + '.pkl', 'rb'))
training_data += pickle.load(open('drive/MyDrive/Bachelorarbeit/Datensatz/Bilder/Bilder 60x34/cs03_' + str(width) + 'x' + str(height) + '.pkl', 'rb'))
training_data += pickle.load(open('drive/MyDrive/Bachelorarbeit/Datensatz/Bilder/Bilder 60x34/cs04_' + str(width) + 'x' + str(height) + '.pkl', 'rb'))

# %%
plt.imshow(training_data[0], cmap = plt.cm.binary)
plt.show()

# %%
print(len(training_data))
# Out:
# 316757

# %% [markdown]
# Normalize the pictures

# %%
training_data = np.divide(training_data, 255.0)

# %%
X_all = []
y_all = []

# %% [markdown]
# This method creats the training set with the given look back

# %%
def create_dataset(dataset, lb):
  X_all = []
  y_all = []

  look_back = lb

  for i in range(look_back, len(dataset)):
    x = []
    for j in range(i-look_back, i):
      x.extend(dataset[j])
    X_all.append(x)
    y_all.append(dataset[i])

  X_all, y_all = np.array(X_all), np.array(y_all)
  y_all = np.reshape(y_all, (len(y_all), width*height), 'C')
  X_all = np.reshape(X_all, (len(X_all), width*height*look_back), 'C')
  return X_all, y_all

# %% [markdown]
# This method sets up the optuna trial

# %%
def objective(trial):
  K.clear_session()

  X_all = []
  y_all = []
  
  hidden_activation = trial.suggest_categorical('activation_hidden_layer', ['relu', 'sigmoid'])
  out_activation = trial.suggest_categorical('activation_layer_out', ['linear', 'sigmoid'])
  optimizer = trial.suggest_categorical('optimizer', ['adam', 'RMSprop'])
  batch_size = trial.suggest_int('batch_size', 32, 512)
  lb = trial.suggest_int('look_back', 2, 3)
  layer_number = trial.suggest_int('layer_number', 5, 7)

  X_all, y_all = create_dataset(training_data, lb)

  model = Sequential()
  
  model.add(Dense(
      units = trial.suggest_int('units_layer_1', 1, 3000)
  ))
  model.add(Dense(
      units = trial.suggest_int('units_layer_2', 1, 3000),
      activation = hidden_activation
  ))
  model.add(Dense(
      units = trial.suggest_int('units_layer_3', 1, 3000),
      activation = hidden_activation
  ))
  model.add(Dense(
      units = trial.suggest_int('units_layer_4', 1, 3000),
      activation = hidden_activation
  ))
  if(layer_number >= 6):
    model.add(Dense(
      units = trial.suggest_int('units_layer_5', 1, 3000),
      activation = hidden_activation
    ))
  if(layer_number == 7):
    model.add(Dense(
      units = trial.suggest_int('units_layer_6', 1, 3000),
      activation = hidden_activation
  ))
  model.add(Dense(
      units = width*height, 
      activation = out_activation
  ))
  model.compile(
      loss = 'mean_squared_error', 
      optimizer = optimizer)
  train_history = model.fit(X_all, y_all, validation_split=0.2, 
                            epochs = 200, 
                            batch_size = batch_size,
                            verbose=0)
  val_loss = train_history.history['val_loss'][0]
  
  return val_loss

# %%
study =  optuna.create_study(direction='minimize')
study.optimize(objective, timeout=82800, gc_after_trial=True)
print("Number of finished trials: {}".format(len(study.trials)))
print("Best trial:")
trial = study.best_trial
print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
  print("    {}: {}".format(key, value))
# Out:
# [I 2022-01-02 13:34:03,207] A new study created in memory with name: no-name-f015523a-b072-49b6-99f8-b03cd1e707ee
# [I 2022-01-02 13:55:36,124] Trial 0 finished with value: 0.015058507211506367 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'linear', 'optimizer': 'adam', 'batch_size': 350, 'look_back': 3, 'layer_number': 7, 'units_layer_1': 291, 'units_layer_2': 276, 'units_layer_3': 63, 'units_layer_4': 1682, 'units_layer_5': 1463, 'units_layer_6': 890}. Best is trial 0 with value: 0.015058507211506367.
# [I 2022-01-02 14:32:51,045] Trial 1 finished with value: 0.03991725668311119 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'linear', 'optimizer': 'RMSprop', 'batch_size': 319, 'look_back': 3, 'layer_number': 5, 'units_layer_1': 2467, 'units_layer_2': 1412, 'units_layer_3': 2164, 'units_layer_4': 147}. Best is trial 0 with value: 0.015058507211506367.
# [I 2022-01-02 15:18:08,961] Trial 2 finished with value: 0.015857188031077385 and parameters: {'activation_hidden_layer': 'sigmoid', 'activation_layer_out': 'linear', 'optimizer': 'adam', 'batch_size': 126, 'look_back': 3, 'layer_number': 6, 'units_layer_1': 1071, 'units_layer_2': 856, 'units_layer_3': 2583, 'units_layer_4': 2563, 'units_layer_5': 509}. Best is trial 0 with value: 0.015058507211506367.
# [I 2022-01-02 15:58:15,886] Trial 3 finished with value: 0.022806202992796898 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'linear', 'optimizer': 'adam', 'batch_size': 126, 'look_back': 3, 'layer_number': 5, 'units_layer_1': 748, 'units_layer_2': 1053, 'units_layer_3': 1703, 'units_layer_4': 1941}. Best is trial 0 with value: 0.015058507211506367.
# [I 2022-01-02 16:54:21,651] Trial 4 finished with value: 0.01802779734134674 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'linear', 'optimizer': 'adam', 'batch_size': 63, 'look_back': 2, 'layer_number': 6, 'units_layer_1': 1773, 'units_layer_2': 1085, 'units_layer_3': 423, 'units_layer_4': 1075, 'units_layer_5': 1020}. Best is trial 0 with value: 0.015058507211506367.
# [I 2022-01-02 17:30:20,118] Trial 5 finished with value: 0.04270605742931366 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'RMSprop', 'batch_size': 252, 'look_back': 2, 'layer_number': 6, 'units_layer_1': 1640, 'units_layer_2': 2015, 'units_layer_3': 971, 'units_layer_4': 2627, 'units_layer_5': 495}. Best is trial 0 with value: 0.015058507211506367.
# [I 2022-01-02 18:39:58,273] Trial 6 finished with value: 0.03997355327010155 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'linear', 'optimizer': 'RMSprop', 'batch_size': 163, 'look_back': 2, 'layer_number': 7, 'units_layer_1': 2762, 'units_layer_2': 1823, 'units_layer_3': 2909, 'units_layer_4': 1742, 'units_layer_5': 2253, 'units_layer_6': 93}. Best is trial 0 with value: 0.015058507211506367.
# [I 2022-01-02 19:16:36,573] Trial 7 finished with value: 0.0401763990521431 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'RMSprop', 'batch_size': 420, 'look_back': 2, 'layer_number': 7, 'units_layer_1': 2852, 'units_layer_2': 1988, 'units_layer_3': 675, 'units_layer_4': 2614, 'units_layer_5': 114, 'units_layer_6': 2341}. Best is trial 0 with value: 0.015058507211506367.
# [I 2022-01-02 19:44:42,614] Trial 8 finished with value: 0.023098137229681015 and parameters: {'activation_hidden_layer': 'sigmoid', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 449, 'look_back': 2, 'layer_number': 6, 'units_layer_1': 2922, 'units_layer_2': 821, 'units_layer_3': 2226, 'units_layer_4': 2255, 'units_layer_5': 351}. Best is trial 0 with value: 0.015058507211506367.
# [I 2022-01-02 20:16:00,770] Trial 9 finished with value: 0.013701029121875763 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 391, 'look_back': 2, 'layer_number': 7, 'units_layer_1': 2059, 'units_layer_2': 2281, 'units_layer_3': 1447, 'units_layer_4': 632, 'units_layer_5': 1750, 'units_layer_6': 1039}. Best is trial 9 with value: 0.013701029121875763.
# [I 2022-01-02 20:50:37,519] Trial 10 finished with value: 0.04000989347696304 and parameters: {'activation_hidden_layer': 'sigmoid', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 480, 'look_back': 2, 'layer_number': 7, 'units_layer_1': 2099, 'units_layer_2': 2778, 'units_layer_3': 1327, 'units_layer_4': 804, 'units_layer_5': 2868, 'units_layer_6': 1568}. Best is trial 9 with value: 0.013701029121875763.
# [I 2022-01-02 21:09:43,692] Trial 11 finished with value: 0.04016819968819618 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 355, 'look_back': 3, 'layer_number': 7, 'units_layer_1': 67, 'units_layer_2': 1, 'units_layer_3': 49, 'units_layer_4': 1165, 'units_layer_5': 1698, 'units_layer_6': 797}. Best is trial 9 with value: 0.013701029121875763.
# [I 2022-01-02 21:29:30,924] Trial 12 finished with value: 0.040975429117679596 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'linear', 'optimizer': 'adam', 'batch_size': 377, 'look_back': 3, 'layer_number': 7, 'units_layer_1': 310, 'units_layer_2': 2610, 'units_layer_3': 3, 'units_layer_4': 276, 'units_layer_5': 1481, 'units_layer_6': 1084}. Best is trial 9 with value: 0.013701029121875763.
# [I 2022-01-02 21:56:07,536] Trial 13 finished with value: 0.022122424095869064 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 250, 'look_back': 3, 'layer_number': 7, 'units_layer_1': 1130, 'units_layer_2': 76, 'units_layer_3': 1483, 'units_layer_4': 653, 'units_layer_5': 1830, 'units_layer_6': 602}. Best is trial 9 with value: 0.013701029121875763.
# [I 2022-01-02 22:29:51,283] Trial 14 finished with value: 0.017931360751390457 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'linear', 'optimizer': 'adam', 'batch_size': 511, 'look_back': 3, 'layer_number': 7, 'units_layer_1': 2167, 'units_layer_2': 2408, 'units_layer_3': 1015, 'units_layer_4': 1456, 'units_layer_5': 1190, 'units_layer_6': 1689}. Best is trial 9 with value: 0.013701029121875763.
# [I 2022-01-02 22:55:30,249] Trial 15 finished with value: 0.01771637238562107 and parameters: {'activation_hidden_layer': 'sigmoid', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 282, 'look_back': 2, 'layer_number': 6, 'units_layer_1': 570, 'units_layer_2': 459, 'units_layer_3': 1852, 'units_layer_4': 1371, 'units_layer_5': 2062}. Best is trial 9 with value: 0.013701029121875763.
# [I 2022-01-02 23:20:44,389] Trial 16 finished with value: 0.01694793812930584 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'linear', 'optimizer': 'adam', 'batch_size': 404, 'look_back': 2, 'layer_number': 7, 'units_layer_1': 1415, 'units_layer_2': 1632, 'units_layer_3': 438, 'units_layer_4': 602, 'units_layer_5': 2497, 'units_layer_6': 1158}. Best is trial 9 with value: 0.013701029121875763.
# [I 2022-01-02 23:51:09,393] Trial 17 finished with value: 0.01183514017611742 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 340, 'look_back': 3, 'layer_number': 5, 'units_layer_1': 1244, 'units_layer_2': 2316, 'units_layer_3': 1223, 'units_layer_4': 1870}. Best is trial 17 with value: 0.01183514017611742.
# [I 2022-01-03 00:33:44,763] Trial 18 finished with value: 0.01976381428539753 and parameters: {'activation_hidden_layer': 'sigmoid', 'activation_layer_out': 'sigmoid', 'optimizer': 'RMSprop', 'batch_size': 217, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 1296, 'units_layer_2': 2987, 'units_layer_3': 1121, 'units_layer_4': 2185}. Best is trial 17 with value: 0.01183514017611742.
# [I 2022-01-03 01:06:31,561] Trial 19 finished with value: 0.0493234246969223 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 312, 'look_back': 3, 'layer_number': 5, 'units_layer_1': 1876, 'units_layer_2': 2188, 'units_layer_3': 1902, 'units_layer_4': 996}. Best is trial 17 with value: 0.01183514017611742.
# [I 2022-01-03 01:31:28,774] Trial 20 finished with value: 0.013960939832031727 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 444, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 2313, 'units_layer_2': 2430, 'units_layer_3': 1329, 'units_layer_4': 365}. Best is trial 17 with value: 0.01183514017611742.
# [I 2022-01-03 01:56:29,374] Trial 21 finished with value: 0.01496456004679203 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 438, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 2307, 'units_layer_2': 2370, 'units_layer_3': 1304, 'units_layer_4': 370}. Best is trial 17 with value: 0.01183514017611742.
# [I 2022-01-03 02:25:07,974] Trial 22 finished with value: 0.043656520545482635 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 388, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 2498, 'units_layer_2': 2549, 'units_layer_3': 1625, 'units_layer_4': 66}. Best is trial 17 with value: 0.01183514017611742.
# [I 2022-01-03 02:47:16,345] Trial 23 finished with value: 0.012802750803530216 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 465, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 1814, 'units_layer_2': 2241, 'units_layer_3': 768, 'units_layer_4': 502}. Best is trial 17 with value: 0.01183514017611742.
# [I 2022-01-03 03:10:29,128] Trial 24 finished with value: 0.011430562473833561 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 329, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 1836, 'units_layer_2': 1540, 'units_layer_3': 734, 'units_layer_4': 730}. Best is trial 24 with value: 0.011430562473833561.
# [I 2022-01-03 03:37:31,912] Trial 25 finished with value: 0.01071358472108841 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 208, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 1525, 'units_layer_2': 1433, 'units_layer_3': 739, 'units_layer_4': 1309}. Best is trial 25 with value: 0.01071358472108841.
# [I 2022-01-03 04:17:45,466] Trial 26 finished with value: 0.03995805233716965 and parameters: {'activation_hidden_layer': 'sigmoid', 'activation_layer_out': 'sigmoid', 'optimizer': 'RMSprop', 'batch_size': 202, 'look_back': 3, 'layer_number': 5, 'units_layer_1': 926, 'units_layer_2': 1423, 'units_layer_3': 476, 'units_layer_4': 2975}. Best is trial 25 with value: 0.01071358472108841.
# [I 2022-01-03 04:41:14,579] Trial 27 finished with value: 0.011111770756542683 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 299, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 1480, 'units_layer_2': 1713, 'units_layer_3': 725, 'units_layer_4': 1196}. Best is trial 25 with value: 0.01071358472108841.
# [I 2022-01-03 05:05:06,526] Trial 28 finished with value: 0.016123173758387566 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 276, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 1448, 'units_layer_2': 1725, 'units_layer_3': 760, 'units_layer_4': 871}. Best is trial 25 with value: 0.01071358472108841.
# [I 2022-01-03 05:39:19,411] Trial 29 finished with value: 0.011681958101689816 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 208, 'look_back': 2, 'layer_number': 6, 'units_layer_1': 1604, 'units_layer_2': 1236, 'units_layer_3': 227, 'units_layer_4': 1287, 'units_layer_5': 2928}. Best is trial 25 with value: 0.01071358472108841.
# [I 2022-01-03 06:04:12,582] Trial 30 finished with value: 0.045917775481939316 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 302, 'look_back': 2, 'layer_number': 6, 'units_layer_1': 1953, 'units_layer_2': 1519, 'units_layer_3': 262, 'units_layer_4': 1551, 'units_layer_5': 851}. Best is trial 25 with value: 0.01071358472108841.
# [I 2022-01-03 06:37:51,231] Trial 31 finished with value: 0.013712444342672825 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 216, 'look_back': 2, 'layer_number': 6, 'units_layer_1': 1606, 'units_layer_2': 1151, 'units_layer_3': 249, 'units_layer_4': 1265, 'units_layer_5': 2902}. Best is trial 25 with value: 0.01071358472108841.
# [I 2022-01-03 07:07:46,598] Trial 32 finished with value: 0.011122552677989006 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 175, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 1583, 'units_layer_2': 1305, 'units_layer_3': 586, 'units_layer_4': 1599}. Best is trial 25 with value: 0.01071358472108841.
# [I 2022-01-03 07:36:07,892] Trial 33 finished with value: 0.010895960964262486 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 168, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 1338, 'units_layer_2': 776, 'units_layer_3': 607, 'units_layer_4': 1658}. Best is trial 25 with value: 0.01071358472108841.
# [I 2022-01-03 08:04:04,759] Trial 34 finished with value: 0.010942931286990643 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 151, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 988, 'units_layer_2': 752, 'units_layer_3': 919, 'units_layer_4': 1606}. Best is trial 25 with value: 0.01071358472108841.
# [I 2022-01-03 08:40:31,412] Trial 35 finished with value: 0.011127249337732792 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 101, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 852, 'units_layer_2': 568, 'units_layer_3': 911, 'units_layer_4': 1751}. Best is trial 25 with value: 0.01071358472108841.
# [I 2022-01-03 09:26:36,157] Trial 36 finished with value: 0.01618644967675209 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'RMSprop', 'batch_size': 117, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 1021, 'units_layer_2': 858, 'units_layer_3': 885, 'units_layer_4': 2255}. Best is trial 25 with value: 0.01071358472108841.
# [I 2022-01-03 09:50:58,151] Trial 37 finished with value: 0.014927523210644722 and parameters: {'activation_hidden_layer': 'sigmoid', 'activation_layer_out': 'linear', 'optimizer': 'adam', 'batch_size': 156, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 712, 'units_layer_2': 511, 'units_layer_3': 1095, 'units_layer_4': 1029}. Best is trial 25 with value: 0.01071358472108841.
# [I 2022-01-03 11:49:34,515] Trial 38 finished with value: 0.014470062218606472 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'RMSprop', 'batch_size': 35, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 1267, 'units_layer_2': 908, 'units_layer_3': 534, 'units_layer_4': 2012}. Best is trial 25 with value: 0.01071358472108841.
# [I 2022-01-03 12:10:39,354] Trial 39 finished with value: 0.011035528033971786 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'sigmoid', 'optimizer': 'adam', 'batch_size': 249, 'look_back': 2, 'layer_number': 5, 'units_layer_1': 1129, 'units_layer_2': 682, 'units_layer_3': 307, 'units_layer_4': 1419}. Best is trial 25 with value: 0.01071358472108841.
# [I 2022-01-03 12:57:20,597] Trial 40 finished with value: 0.010607389733195305 and parameters: {'activation_hidden_layer': 'relu', 'activation_layer_out': 'linear', 'optimizer': 'adam', 'batch_size': 87, 'look_back': 2, 'layer_number': 6, 'units_layer_1': 568, 'units_layer_2': 731, 'units_layer_3': 329, 'units_layer_4': 1703, 'units_layer_5': 2550}. Best is trial 40 with value: 0.010607389733195305.
# Number of finished trials: 41
# Best trial:
#   Value: 0.010607389733195305
#   Params:
#     activation_hidden_layer: relu
#     activation_layer_out: linear
#     optimizer: adam
#     batch_size: 87
#     look_back: 2
#     layer_number: 6
#     units_layer_1: 568
#     units_layer_2: 731
#     units_layer_3: 329
#     units_layer_4: 1703
#     units_layer_5: 2550

# %% [markdown]
# Value: 0.010607389733195305
# Params:
# - activation_hidden_layer: relu
# - activation_layer_out: linear
# - optimizer: adam
# - batch_size: 87
# - look_back: 2
# - layer_number: 6
# - units_layer_1: 568
# - units_layer_2: 731
# - units_layer_3: 329
# - units_layer_4: 1703
# - units_layer_5: 2550

# %% [markdown]
# Create the training dataset with look back 2

# %%
X_all, y_all = create_dataset(training_data, 2)

# %% [markdown]
# Train the suggestet model from optuna

# %%
model = Sequential()
model.add(Dense(568))
model.add(Dense(731, activation='relu'))
model.add(Dense(329, activation='relu'))
model.add(Dense(1703, activation='relu'))
model.add(Dense(2550, activation='relu'))
model.add(Dropout(0.2)) #also trained with 0.5 or without a dropout layer
model.add(Dense(width*height, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error')

filepath = 'drive/MyDrive/pictureNN_4/weights-improvement-{epoch:d}.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

model.fit(X_all, y_all, validation_split=0.2, epochs=3500, batch_size=87, callbacks=callbacks_list, verbose=2)

model.save('drive/MyDrive/pictureNN_4/3500.hdf5')

# %% [markdown]
# Load the model with the best validation loss

# %%
best_val_model = Sequential()
best_val_model.add(Dense(568))
best_val_model.add(Dense(731, activation='relu'))
best_val_model.add(Dense(329, activation='relu'))
best_val_model.add(Dense(1703, activation='relu'))
best_val_model.add(Dense(2550, activation='relu'))
best_val_model.add(Dense(width*height, activation='linear'))

best_val_model = keras.models.load_model('drive/MyDrive/pictureNN/weights-improvement-3.hdf5')

# %% [markdown]
# Calculate the duration of a prediction

# %%
import time
start_time = time.time()
predict = best_val_model.predict(X_all)
duration = time.time() - start_time
print("--- %s seconds ---" % (duration))
print(duration/len(X_all))
# Out:
# --- 23.27078604698181 seconds ---
# 7.346619957690268e-05

# %% [markdown]
# --- 23.27078604698181 seconds ---
#
# 7.346619957690268e-05

# %% [markdown]
# Calculate the training error

# %%
import math
trainScore = math.sqrt(mean_squared_error(y_all[:], predict[:]))
print('Score: %.4f RMSE' % (trainScore))
# Out:
# Score: 0.0916 RMSE

# %% [markdown]
# Score: 0.0916 RMSE

# %% [markdown]
# Load the test set
# (Before doing this the ram has to be resetet)

# %%
test_data = pickle.load(open('drive/MyDrive/Bachelorarbeit/Datensatz/Bilder/Bilder 60x34/cs06_' + str(width) + 'x' + str(height) + '.pkl', 'rb'))
test_data += pickle.load(open('drive/MyDrive/Bachelorarbeit/Datensatz/Bilder/Bilder 60x34/cs07_' + str(width) + 'x' + str(height) + '.pkl', 'rb'))

# %%
print(len(test_data))
# Out:
# 154013

# %%
test_data = np.divide(test_data, 255.0)

# %%
X_all, y_all = create_dataset(test_data, 2)

# %%
len(X_all)
# Out:
# 154011

# %% [markdown]
# Take a look at the predictions

# %%
testPredict = best_val_model.predict(X_all)

# %%
pic_number = 40000

# %%
test_picture = y_all[pic_number]
test_picture = np.reshape(test_picture, (height, width))

# %%
plt.imshow(test_picture, cmap = plt.cm.binary)
plt.show()

# %%
predicted_picture = testPredict[pic_number]
predicted_picture = np.reshape(predicted_picture, (height, width))

# %%
plt.imshow(predicted_picture, cmap = plt.cm.binary)
plt.show()

# %% [markdown]
# Save the example pictures

# %%
from PIL import Image
test_picture = np.multiply(test_picture, 255.0)
im = Image.fromarray(test_picture)
im = im.convert('L')
im.save('drive/MyDrive/bilder_ba/test_pic_60x34_5.png')
predicted_picture = np.multiply(predicted_picture, 255.0)
im = Image.fromarray(predicted_picture)
im = im.convert('L')
im.save('drive/MyDrive/bilder_ba/pre_pic_60x34_5.png')

# %% [markdown]
# Calculate the test error

# %%
testScore = math.sqrt(mean_squared_error(y_all[:], testPredict[:]))
print('Score: %.4f RMSE' % (testScore))
# Out:
# Score: 0.0953 RMSE
